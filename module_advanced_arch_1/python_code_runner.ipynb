# %%
# %run resnet50_from_scratch.py --batch-size 4 --num-classes 10 --show-shapes
# Out:
# Input:          torch.Size([4, 3, 224, 224])
# After conv1:    torch.Size([4, 64, 112, 112])
# After maxpool:  torch.Size([4, 64, 56, 56])
# After layer1:   torch.Size([4, 256, 56, 56])
# After layer2:   torch.Size([4, 512, 28, 28])
# After layer3:   torch.Size([4, 1024, 14, 14])
# After layer4:   torch.Size([4, 2048, 7, 7])
# After avgpool:  torch.Size([4, 2048, 1, 1])
# After flatten:  torch.Size([4, 2048])
# After fc:       torch.Size([4, 10])
#
# Model created successfully.
# Trainable parameters: 23,528,522
# Output shape: (4, 10)
# Output Logits: tensor([[ 0.0079,  0.0204,  0.0059,  0.0009,  0.0003,  0.0164,  0.0023, -0.0133,
#           0.0125, -0.0241],
#         [ 0.0088,  0.0204,  0.0062,  0.0002,  0.0006,  0.0177,  0.0018, -0.0120,
#           0.0127, -0.0239],
#         [ 0.0098,  0.0190,  0.0064,  0.0013,  0.0004,  0.0181,  0.0034, -0.0131,
#           0.0121, -0.0235],
#         [ 0.0093,  0.0190,  0.0068,  0.0011,  0.0004,  0.0171,  0.0020, -0.0130,
# ...
